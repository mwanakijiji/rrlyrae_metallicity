# %%
# This increases the pipeline H, K EW errors to check if MCMC is not converging 
# because they are too small

# Created 2020 Jan 14 by E.S.

# %%
import pandas as pd

# %%
df = pd.read_csv("./rrlyrae_metallicity/bin/hk_data_winnowed.csv")

# %%
df["err_K"] = 0.2*df["K"]
df["err_balmer"] = 0.2*df["balmer"]

# %%
df.to_csv("./rrlyrae_metallicity/bin/test_hk_data_winnowed.csv")

# %%
df
# Out:
#      Unnamed: 0  level_0  index  Unnamed: 0.1 original_spec_file_name  \
# 0             0        0     26            26           600025m05.smo
# 1             1        1     27            27           600025m10.smo
# 2             2        2     28            28           600025m15.smo
# 3             3        3     29            29           600025m20.smo
# 4             4        4     30            30           600025m25.smo
# 5             5        5     31            31           600025m30.smo
# 6             6        6     32            32           600025p00.smo
# 7             7        7     33            33           600030m05.smo
# 8             8        8     34            34           600030m10.smo
# 9             9        9     35            35           600030m15.smo
# 10           10       10     36            36           600030m20.smo
# 11           11       11     37            37           600030m25.smo
# ...
