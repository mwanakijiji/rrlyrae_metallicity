# %%
# This reads in a csv with scraped data and calculated errors, and allows displays to check

# Created 2021 Oct. 31 by E.S.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/bandari/Documents/git.repos/rrlyrae_metallicity/ew_products/restacked_ew_w_metadata.csv")

# %%
df.keys()
# Out:
# Index(['realization_spec_file_name', 'orig_spec_file_name', 'EW_Hbeta',
#        'err_EW_Hbeta_from_robo', 'EW_Hdelta', 'err_EW_Hdelta_from_robo',
#        'EW_Hgamma', 'err_EW_Hgamma_from_robo', 'EW_Heps',
#        'err_EW_Heps_from_robo', 'EW_CaIIK', 'err_EW_CaIIK_from_robo',
#        'EW_Balmer', 'err_EW_Balmer_based_Robo',
#        'err_EW_Balmer_based_noise_churning', 'subtype', 'phase', 'feh',
#        'err_feh', 'teff', 'logg', 'alpha'],
#       dtype='object')

# %%
plt.hist(df["err_EW_Balmer_based_Robo"], bins=100)
plt.xlabel("EW of net Balmer line (angstr)")
plt.savefig("junk_net_balmer_robo_error.pdf")

# %%
plt.hist(df["EW_Balmer"], bins=100)
plt.xlabel("EW of net Balmer (angstr)")
plt.savefig("junk_net_Balmer_robo.pdf")

# %%
plt.hist(df["err_EW_Hdelta_from_robo"], bins=100)
plt.xlabel("EW of Hdelta (angstr)")
plt.savefig("junk_Hdelta_robo_error.pdf")

# %%
plt.hist(df["EW_Hdelta"], bins=100)
plt.xlabel("EW of Hdelta (angstr)")
plt.savefig("junk_net_Hdelta_robo.pdf")

# %%
plt.hist(df["err_EW_Hgamma_from_robo"], bins=100)
plt.xlabel("EW of Hgamma (angstr)")
plt.savefig("junk_net_Hgamma_robo_error.pdf")

# %%
plt.hist(df["EW_Hgamma"], bins=100)
plt.xlabel("EW of Hgamma (angstr)")
plt.savefig("junk_net_Hgamma_robo.pdf")

# %%
plt.hist(df["err_EW_Balmer_based_noise_churning"], bins=100)
plt.savefig("junk_net_balmer_noise_churn_error.pdf")
