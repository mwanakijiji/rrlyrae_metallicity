# %%
# Make new columns in input tables

# Created by E.S. from parent make_spectrum_noise_values, Jan 12, 2020

# %%
import glob
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
source_dir = ("/Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/"+
              "rrlyrae_metallicity/src/synthetic_spectra_RW/rrmods_all/")
#write_dir = ("/Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/"+
#             "rrlyrae_metallicity/src/synthetic_spectra_RW/"+
#             "junk_test2_lots_of_noise_rrmods_all/")
write_dir = ("/Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/"+
             "rrlyrae_metallicity/src/synthetic_spectra_RW/"+
             "junk_test3_sn_10_rrmods_all/")

# %%
source_dir
# Out:
# '/Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/rrmods_all/'

# %%
#np.nanmedian(np.divide(df["flux"],df["error"]))

# %%
# accumulate list of filenames of normalized synthetic spectra
file_name_list = glob.glob(source_dir + "*smo") # (or search whatever other directory the *.c.dat files are in)

# for-loop to write out *.robolines and *.robospect files
for p in file_name_list: 
    print(p)
    df = pd.read_csv(p, delim_whitespace=True, names=["wavel","flux","error"])
    
    # make noise error equal to zero (or whatever)
    '''
    df["error"] = 1e-8
    '''
    df["error"] = np.divide(df["flux"],10)
    
    print(write_dir+os.path.basename(p))
    print('---')
    
    df.to_csv(write_dir+os.path.basename(p), sep=' ', index=False, header=False)
# Out:
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/rrmods_all/725030p02.smo
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/junk_test3_sn_10_rrmods_all/725030p02.smo
# ---
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/rrmods_all/775030m15.smo
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/junk_test3_sn_10_rrmods_all/775030m15.smo
# ---
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/rrmods_all/725025m25.smo
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/junk_test3_sn_10_rrmods_all/725025m25.smo
# ---
# /Users/nyumbani/Documents/git.repos/rrlyrae_metallicity/rrlyrae_metallicity/src/synthetic_spectra_RW/rrmods_all/575025m15.smo
# ...

# %%
# add column to a single file

df = pd.read_csv("../rrlyrae_metallicity/junk_test_no_noise_rw_spectra/src/spec_phases_RW_spectra.list", 
                 delim_whitespace=True)

# %%
df["Teff"] = np.nan
df["logg"] = np.nan

# %%
for r in range(0,len(df)):
    df["Teff"][r] = df["Spectrum"][r][0:4]
    df["logg"][r] = np.divide(float(df["Spectrum"][r][4:6]),10)
# Out:
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/nyumbani/anaconda3/envs/py366/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#           Spectrum   Star Subtype  Phase  final_FeH  final_err_FeH    Teff  \
# 0    575020m05.smo  20m05      ab    0.5       -0.5           0.15  5750.0
# 1    575020m10.smo  20m10      ab    0.5       -1.0           0.15  5750.0
# 2    575020m15.smo  20m15      ab    0.5       -1.5           0.15  5750.0
# 3    575020m20.smo  20m20      ab    0.5       -2.0           0.15  5750.0
# 4    575020m25.smo  20m25      ab    0.5       -2.5           0.15  5750.0
# 5    575020m30.smo  20m30      ab    0.5       -3.0           0.15  5750.0
# 6    575020p00.smo  20p00      ab    0.5        0.0           0.15  5750.0
# 7    575020p02.smo  20p02      ab    0.5        0.2           0.15  5750.0
# 8    575025m05.smo  25m05      ab    0.5       -0.5           0.15  5750.0
# 9    575025m10.smo  25m10      ab    0.5       -1.0           0.15  5750.0
# 10   575025m15.smo  25m15      ab    0.5       -1.5           0.15  5750.0
# ...

# %%
df["Subtype"] = "ab"
df["final_err_FeH"] = 0.15
df["Phase"] = 0.5

# %%
df
# Out:
#           Spectrum   Star Subtype  Phase  final_FeH  final_err_FeH
# 0    575020m05.smo  20m05      ab    0.5      -0.50           0.15
# 1    575020m10.smo  20m10      ab    0.5      -1.00           0.15
# 2    575020m15.smo  20m15      ab    0.5      -1.50           0.15
# 3    575020m20.smo  20m20      ab    0.5      -2.00           0.15
# 4    575020m25.smo  20m25      ab    0.5      -2.50           0.15
# 5    575020m30.smo  20m30      ab    0.5      -3.00           0.15
# 6    575020p00.smo  20p00      ab    0.5       0.00           0.15
# 7    575020p02.smo  20p02      ab    0.5       0.20           0.15
# 8    575025m05.smo  25m05      ab    0.5      -0.50           0.15
# 9    575025m10.smo  25m10      ab    0.5      -1.00           0.15
# 10   575025m15.smo  25m15      ab    0.5      -1.50           0.15
# 11   575025m20.smo  25m20      ab    0.5      -2.00           0.15
# 12   575025m25.smo  25m25      ab    0.5      -2.50           0.15
# ...

# %%
df.to_csv("junk.csv", sep = " ", index=False)

# %%
row_of_interest = df.where(df["Spectrum"] == "575020m10.smo").dropna()
#feh_of_interest = row_of_interest.iloc[0]["final_FeH"]

# %%
row_of_interest["final_FeH"].values[0]
# Out:
# -1.0
