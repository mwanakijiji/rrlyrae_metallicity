# %%
# This plots BIC values for different permutations of coefficients

# Created 2020 Mar 10 by E.S.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv("data/test_bic_output.csv",delimiter=";")

# %%
df2
# Out:
#                         ('f', 'g', 'h', 'k', 'm', 'n')  -85.67271208165431  \
# 0      1.28187489e-01  1.34855452e+00  2.45785445e-...                 NaN
# 1                     -2.19815048e-03  2.38082641e-02]             7X2ZMRE
# 2                                            ('NaN1',)  168.61055973367195
# 3      5.00000000e-21  5.00000000e-21  5.00000000e-...                 NaN
# 4                      5.00000000e-21  5.00000000e-21]             POTSALS
# ..                                                 ...                 ...
# 126    6.59609984e-01  9.95024875e-21  5.41710803e-...                 NaN
# 127                   -5.05293104e-02  9.93926241e-02]             JQH3HZH
# 128                                         ('h', 'm')    289.023136735165
# 129    4.97512438e-23  6.75968047e-21  5.00000000e-...                 NaN
# 130                   -2.31048980e-03  1.68485452e-21]             7Y2QUQB
#
#       10    108  31.66888665399313  108.1  \
# ...

# %%
df = pd.read_csv("data/test_bic_output.csv",names=["coeffs_array",
                                              "bic",
                                              "n_params",
                                              "n_samples",
                                              "ssr",
                                              "n_samples_dup",
                                              "pfinal",
                                              "res"],delimiter=";")

# %%
df = pd.read_csv("data/test_bic_output.csv",names=["coeffs_array",
                                              "bic",
                                              "n_params",
                                              "n_samples",
                                              "ssr",
                                              "n_samples_dup",
                                              "pfinal",
                                              "res"],delimiter=";")

# %%
df
# Out:
#                                           coeffs_array                 bic  \
# 0                       ('f', 'g', 'h', 'k', 'm', 'n')  -85.67271208165431
# 1      1.28187489e-01  1.34855452e+00  2.45785445e-...                 NaN
# 2                     -2.19815048e-03  2.38082641e-02]             7X2ZMRE
# 3                                            ('NaN1',)  168.61055973367195
# 4      5.00000000e-21  5.00000000e-21  5.00000000e-...                 NaN
# ..                                                 ...                 ...
# 127    6.59609984e-01  9.95024875e-21  5.41710803e-...                 NaN
# 128                   -5.05293104e-02  9.93926241e-02]             JQH3HZH
# 129                                         ('h', 'm')    289.023136735165
# 130    4.97512438e-23  6.75968047e-21  5.00000000e-...                 NaN
# 131                   -2.31048980e-03  1.68485452e-21]             7Y2QUQB
#
#      n_params  n_samples          ssr  n_samples_dup  \
# ...
